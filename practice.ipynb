# %% [markdown]
# <a href="https://colab.research.google.com/github/lakshmijs021-ux/collab/blob/main/practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
a= np.array([21,14,24])
print(a)
# Out:
# [21 14 24]

# %%
import pandas as pd
data = {"name":["lakshmi", " chandana:","sinchana "],"age":[21,14,24]}
df= pd.DataFrame(data)
print(df)
# Out:
#          name  age
# 0     lakshmi   21
# 1   chandana:   14
# 2   sinchana    24

# %%
import pandas as pd
df = pd.read_csv("/content/sample_data/california_housing_test.csv")
print(df.head())
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5,6,7,8]
y=[5,10,5,10,5,10,5,10]
plt.plot(x,y)
plt.show()
